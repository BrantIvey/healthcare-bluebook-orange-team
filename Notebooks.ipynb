# %%
import pandas as pd

# %%
CBSA_ZIP_032020 = pd.read_excel('CBSA_ZIP_032020.xlsx')

# %%
CBSA_ZIP_032020.head()
# Out:
#     CBSA    ZIP  RES_RATIO  BUS_RATIO  OTH_RATIO  TOT_RATIO
# 0  10100  57445   0.044115   0.016156   0.037037   0.041101
# 1  10100  57456   0.000046   0.000000   0.000000   0.000039
# 2  10100  57441   0.014690   0.003401   0.000639   0.012785
# 3  10100  57474   0.005792   0.003401   0.001277   0.005295
# 4  10100  57401   0.751576   0.788265   0.933589   0.766139

# %%
MUP_OHP_R19_P04_V10_D17_APC_Provider = pd.read_excel('MUP_OHP_R19_P04_V10_D17_APC_Provider.xlsx',header=5)

# %%
MUP_OHP_R19_P04_V10_D17_APC_Provider.head()
# Out:
#    Provider ID                     Provider Name Provider Street Address  \
# 0        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 1        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 2        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 3        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 4        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
#
#   Provider City Provider\nState  Provider\nZip Code  \
# 0        Dothan              AL               36301
# 1        Dothan              AL               36301
# 2        Dothan              AL               36301
# 3        Dothan              AL               36301
# 4        Dothan              AL               36301
#
#   Provider\nHospital Referral Region\n(HRR)   APC  \
# 0                               AL - Dothan  5072
# 1                               AL - Dothan  5073
# 2                               AL - Dothan  5091
# ...

# %%
january_web_addendum_b = pd.read_excel('2020_january_web_addendum_b.12312019.xlsx', header = 2)

# %%
january_web_addendum_b.head()
# Out:
#   HCPCS Code            Short Descriptor SI  APC   Relative Weight  \
# 0      00100       Anesth salivary gland  N   NaN              NaN
# 1      00102  Anesth repair of cleft lip  N   NaN              NaN
# 2      00103       Anesth blepharoplasty  N   NaN              NaN
# 3      00104         Anesth electroshock  N   NaN              NaN
# 4      00120          Anesth ear surgery  N   NaN              NaN
#
#    Payment Rate  National Unadjusted Copayment   \
# 0            NaN                            NaN
# 1            NaN                            NaN
# 2            NaN                            NaN
# 3            NaN                            NaN
# 4            NaN                            NaN
#
#    Minimum Unadjusted Copayment   \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
# ...

# %%
Medicare_Provider_DF = pd.read_csv('Medicare_Provider_Util_Payment_PUF_CY2017.txt', sep='\t')

# %%
Medicare_Provider_DF = Medicare_Provider_DF.drop(Medicare_Provider_DF.index[0])

# %%
Medicare_Provider_DF.head()
# Out:
#           npi nppes_provider_last_org_name nppes_provider_first_name  \
# 1  1003000126                    ENKESHAFI                   ARDALAN
# 2  1003000126                    ENKESHAFI                   ARDALAN
# 3  1003000126                    ENKESHAFI                   ARDALAN
# 4  1003000126                    ENKESHAFI                   ARDALAN
# 5  1003000126                    ENKESHAFI                   ARDALAN
#
#   nppes_provider_mi nppes_credentials nppes_provider_gender nppes_entity_code  \
# 1               NaN              M.D.                     M                 I
# 2               NaN              M.D.                     M                 I
# 3               NaN              M.D.                     M                 I
# 4               NaN              M.D.                     M                 I
# 5               NaN              M.D.                     M                 I
#
#   nppes_provider_street1 nppes_provider_street2 nppes_provider_city  ...  \
# ...
