# %%
import pandas as pd 
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns

# %matplotlib inline

# %%
Outpatient_Hospital_df = pd.read_csv('../notebooks/Provider_Outpatient_Hospital_Charge_Data_by_APC__CY2017 (1).csv')
Outpatient_Hospital_df
# Out:
#        Provider_ID                             Provider_Name  \
# 0            10001          Southeast Alabama Medical Center
# 1            10001          Southeast Alabama Medical Center
# 2            10001          Southeast Alabama Medical Center
# 3            10001          Southeast Alabama Medical Center
# 4            10001          Southeast Alabama Medical Center
# ...            ...                                       ...
# 61774       670122  Houston Methodist The Woodlands Hospital
# 61775       670122  Houston Methodist The Woodlands Hospital
# 61776       670122  Houston Methodist The Woodlands Hospital
# 61777       670122  Houston Methodist The Woodlands Hospital
# 61778       670122  Houston Methodist The Woodlands Hospital
#
#          Provider_Street_Address  Provider_City Provider_State  \
# 0         1108 Ross Clark Circle         Dothan             AL
# 1         1108 Ross Clark Circle         Dothan             AL
# ...

# %%
initial_dataset = pd.read_csv (
    Outpatient_Hospital_df,
    sep='\t',
    usecols=['Provider_ID','Provider_Zip_Code','APC','Beneficiaries','CAPC_Services','Average_Total_Submitted_Charges','Average_Medicare_Allowed_Amount',
            'Average_Medicare_Payment_Amount'],
    dtype= {'Provider_Zip_Code':'str'}
 )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-7f64225d36da> in <module>
#       4     usecols=['Provider_ID','Provider_Zip_Code','APC','Beneficiaries','CAPC_Services','Average_Total_Submitted_Charges','Average_Medicare_Allowed_Amount',
#       5             'Average_Medicare_Payment_Amount'],
# ----> 6     dtype= {'Provider_Zip_Code':'str'}
#       7  )
#       8
#
# ...

# %%
Outpatient_Hospital_df.head(5)
# Out:
#    Provider_ID                     Provider_Name Provider_Street_Address  \
# 0        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 1        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 2        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 3        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 4        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
#
#   Provider_City Provider_State  Provider_Zip_Code Provider_HRR   APC  \
# 0        Dothan             AL              36301  AL - Dothan  5072
# 1        Dothan             AL              36301  AL - Dothan  5073
# 2        Dothan             AL              36301  AL - Dothan  5091
# 3        Dothan             AL              36301  AL - Dothan  5092
# 4        Dothan             AL              36301  AL - Dothan  5112
#
#                                             APC_Desc  Beneficiaries  \
# ...

# %%
Outpatient_Hospital_df.tail(5)
# Out:
#        Provider_ID                             Provider_Name  \
# 61774       670122  Houston Methodist The Woodlands Hospital
# 61775       670122  Houston Methodist The Woodlands Hospital
# 61776       670122  Houston Methodist The Woodlands Hospital
# 61777       670122  Houston Methodist The Woodlands Hospital
# 61778       670122  Houston Methodist The Woodlands Hospital
#
#          Provider_Street_Address  Provider_City Provider_State  \
# 61774  17201 Interstate 45 South  The Woodlands             TX
# 61775  17201 Interstate 45 South  The Woodlands             TX
# 61776  17201 Interstate 45 South  The Woodlands             TX
# 61777  17201 Interstate 45 South  The Woodlands             TX
# 61778  17201 Interstate 45 South  The Woodlands             TX
#
#        Provider_Zip_Code  Provider_HRR   APC  \
# 61774              77385  TX - Houston  5361
# 61775              77385  TX - Houston  5373
# 61776              77385  TX - Houston  5375
# ...

# %%
APC_5302_df = Outpatient_Hospital_df.loc[
    Outpatient_Hospital_df['APC'] == 5302
]

# %%
APC_5302_df.head()
# Out:
#      Provider_ID                     Provider_Name  \
# 22         10001  Southeast Alabama Medical Center
# 60         10005     Marshall Medical Center South
# 90         10006    Eliza Coffee Memorial Hospital
# 126        10011                 St Vincent's East
# 141        10012    Dekalb Regional Medical Center
#
#         Provider_Street_Address Provider_City Provider_State  \
# 22       1108 Ross Clark Circle        Dothan             AL
# 60   2505 U S Highway 431 North          Boaz             AL
# 90           205 Marengo Street      Florence             AL
# 126  50 Medical Park East Drive    Birmingham             AL
# 141        200 Med Center Drive    Fort Payne             AL
#
#      Provider_Zip_Code     Provider_HRR   APC                     APC_Desc  \
# 22               36301      AL - Dothan  5302  Level 2 Upper GI Procedures
# 60               35957  AL - Birmingham  5302  Level 2 Upper GI Procedures
# ...

# %%
APC_5302_df.tail()
# Out:
#        Provider_ID                                      Provider_Name  \
# 61692       670096              Bay Area Regional Medical Center, Llc
# 61708       670102                              Ad Hospital East, Llc
# 61712       670103                              Medical City Alliance
# 61727       670108  Baylor Scott & White Medical Center - Marble F...
# 61773       670122           Houston Methodist The Woodlands Hospital
#
#              Provider_Street_Address  Provider_City Provider_State  \
# 61692             200 Blossom Street        Webster             TX
# 61708  12950 East Freeway, Suite 100        Houston             TX
# 61712     3101 North Tarrant Parkway     Fort Worth             TX
# 61727               810 W Highway 71   Marble Falls             TX
# 61773      17201 Interstate 45 South  The Woodlands             TX
#
#        Provider_Zip_Code     Provider_HRR   APC                     APC_Desc  \
# ...

# %%
APC_5302_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2261 entries, 22 to 61773
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Provider_ID                      2261 non-null   int64
#  1   Provider_Name                    2261 non-null   object
#  2   Provider_Street_Address          2261 non-null   object
#  3   Provider_City                    2261 non-null   object
#  4   Provider_State                   2261 non-null   object
#  5   Provider_Zip_Code                2261 non-null   int64
#  6   Provider_HRR                     2261 non-null   object
#  7   APC                              2261 non-null   int64
#  8   APC_Desc                         2261 non-null   object
#  9   Beneficiaries                    2209 non-null   float64
#  10  CAPC_Services                    2261 non-null   int64
#  11  Average_Total_Submitted_Charges  2261 non-null   float64
# ...
