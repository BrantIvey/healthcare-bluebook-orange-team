# %%
import pandas as pd 
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns

# %matplotlib inline

# %%
january_web_addendum_df = pd.read_csv('../notebooks/2020_january_web_addendum_a.12312019.csv',header=1)

# %%
january_web_addendum_df
# Out:
#      APC                     Group Title SI  Relative Weight  Payment Rate  \
# 0      701                Sr89 strontium  K               NaN   $2,045.702
# 1      726     Dexrazoxane HCl injection  K               NaN     $197.523
# 2      731        Sargramostim injection  K               NaN      $43.504
# 3      736   Amphotericin b liposome inj  K               NaN      $26.726
# 4      738                   Rasburicase  K               NaN     $292.331
# ..     ...                           ... ..               ...          ...
# 763   9532  RBC, frz/deg/wsh, l/r, irrad  R            2.9909      $241.64
# 764   9533      RBC, l/r, cmv-neg, irrad  R            3.0548      $246.81
# 765   9534  Pathogen reduced plasma pool  R            0.3998       $32.30
# 766   9535  Pathogen reduced plasma sing  R            0.9915       $80.11
# 767   9536  Platelets pheresis path redu  R            7.5750      $612.01
#
#     National Unadjusted Copayment  Minimum Unadjusted Copayment   \
# ...

# %%
january_web_addendum_df.loc[
    january_web_addendum_df['unnamed0'] == 5302]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'unnamed0'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-33df7fccac7f> in <module>
#       1 january_web_addendum_df.loc[
# ...
