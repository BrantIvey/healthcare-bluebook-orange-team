# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
ZIP_to_CBSA = pd.read_excel('CBSA_ZIP_032020.xlsx')

# %%
ZIP_to_CBSA.rename(columns = {'ZIP':'zip'}, inplace = True)

# %%
ZIP_to_CBSA.head()
# Out:
#     CBSA    zip  RES_RATIO  BUS_RATIO  OTH_RATIO  TOT_RATIO
# 0  10100  57445   0.044115   0.016156   0.037037   0.041101
# 1  10100  57456   0.000046   0.000000   0.000000   0.000039
# 2  10100  57441   0.014690   0.003401   0.000639   0.012785
# 3  10100  57474   0.005792   0.003401   0.001277   0.005295
# 4  10100  57401   0.751576   0.788265   0.933589   0.766139

# %%
Hospital_Outpatient = pd.read_excel('MUP_OHP_R19_P04_V10_D17_APC_Provider.xlsx',header=5)

# %%
Hospital_Outpatient
# Out:
#        Provider ID                             Provider Name  \
# 0            10001          Southeast Alabama Medical Center
# 1            10001          Southeast Alabama Medical Center
# 2            10001          Southeast Alabama Medical Center
# 3            10001          Southeast Alabama Medical Center
# 4            10001          Southeast Alabama Medical Center
# ...            ...                                       ...
# 61774       670122  Houston Methodist The Woodlands Hospital
# 61775       670122  Houston Methodist The Woodlands Hospital
# 61776       670122  Houston Methodist The Woodlands Hospital
# 61777       670122  Houston Methodist The Woodlands Hospital
# 61778       670122  Houston Methodist The Woodlands Hospital
#
#          Provider Street Address  Provider City Provider\nState  \
# 0         1108 Ross Clark Circle         Dothan              AL
# 1         1108 Ross Clark Circle         Dothan              AL
# 2         1108 Ross Clark Circle         Dothan              AL
# 3         1108 Ross Clark Circle         Dothan              AL
# 4         1108 Ross Clark Circle         Dothan              AL
# ...                          ...            ...             ...
# 61774  17201 Interstate 45 South  The Woodlands              TX
# 61775  17201 Interstate 45 South  The Woodlands              TX
# 61776  17201 Interstate 45 South  The Woodlands              TX
# 61777  17201 Interstate 45 South  The Woodlands              TX
# 61778  17201 Interstate 45 South  The Woodlands              TX
#
#        Provider\nZip Code Provider\nHospital Referral Region\n(HRR)   APC  \
# 0                   36301                               AL - Dothan  5072
# 1                   36301                               AL - Dothan  5073
# 2                   36301                               AL - Dothan  5091
# 3                   36301                               AL - Dothan  5092
# 4                   36301                               AL - Dothan  5112
# ...                   ...                                       ...   ...
# 61774               77385                              TX - Houston  5361
# 61775               77385                              TX - Houston  5373
# 61776               77385                              TX - Houston  5375
# 61777               77385                              TX - Houston  5431
# 61778               77385                              TX - Houston  8011
#
#                                         APC\nDescription  Beneficiaries  \
# 0        Level 2 Excision/ Biopsy/ Incision and Drainage          249.0
# 1        Level 3 Excision/ Biopsy/ Incision and Drainage           52.0
# 2      Level 1 Breast/Lymphatic Surgery and Related P...           26.0
# 3      Level 2 Breast/Lymphatic Surgery and Related P...           23.0
# 4                     Level 2 Musculoskeletal Procedures           17.0
# ...                                                  ...            ...
# 61774           Level 1 Laparoscopy and Related Services           18.0
# 61775               Level 3 Urology and Related Services           11.0
# 61776               Level 5 Urology and Related Services           20.0
# 61777                           Level 1 Nerve Procedures            NaN
# 61778                 Comprehensive Observation Services          156.0
#
#        Comprehensive APC\nServices  \
# 0                              259
# 1                               53
# 2                               27
# 3                               23
# 4                               17
# ...                            ...
# 61774                           18
# 61775                           11
# 61776                           21
# 61777                           12
# 61778                          165
#
#        Average\nEstimated\nTotal\nSubmitted\nCharges  \
# 0                                        9575.005714
# 1                                       12578.280189
# 2                                       11337.608889
# 3                                       17116.158261
# 4                                        7382.732353
# ...                                              ...
# 61774                                   54778.807778
# 61775                                   28237.564545
# 61776                                   35109.678095
# 61777                                   25194.958333
# 61778                                   26580.472485
#
#        Average\nMedicare\nAllowed\nAmount  Average\nMedicare\nPayment\nAmount  \
# 0                             1038.454672                          826.277954
# 1                             1792.596792                         1423.246792
# 2                             2113.580000                         1683.990000
# 3                             3737.140000                         2977.550000
# 4                             1029.460000                          820.210000
# ...                                   ...                                 ...
# 61774                         3866.822778                         3044.482778
# 61775                         1469.871818                         1147.781818
# 61776                         3356.890000                         2674.590000
# 61777                         1506.380000                         1200.200000
# 61778                         2141.540000                         1706.270000
#
#        Outlier\nComprehensive\nAPC\nServices  \
# 0                                        NaN
# 1                                        NaN
# 2                                        0.0
# 3                                        0.0
# 4                                        0.0
# ...                                      ...
# 61774                                   13.0
# 61775                                    NaN
# 61776                                    NaN
# 61777                                    NaN
# 61778                                   40.0
#
#        Average\nMedicare\nOutlier\nAmount
# 0                                     NaN
# 1                                     NaN
# 2                                0.000000
# 3                                0.000000
# 4                                0.000000
# ...                                   ...
# 61774                         1623.728077
# 61775                                 NaN
# 61776                                 NaN
# 61777                                 NaN
# 61778                         1705.106900
#
# [61779 rows x 16 columns]

# %%
APC_to_CPT_HPCS = pd.read_excel('2020_january_web_addendum_b.12312019.xlsx', header = 2)

# %%
APC_to_CPT_HPCS
# Out:
#       HCPCS Code             Short Descriptor  SI  APC   Relative Weight  \
# 0          00100        Anesth salivary gland   N   NaN              NaN
# 1          00102   Anesth repair of cleft lip   N   NaN              NaN
# 2          00103        Anesth blepharoplasty   N   NaN              NaN
# 3          00104          Anesth electroshock   N   NaN              NaN
# 4          00120           Anesth ear surgery   N   NaN              NaN
# ...          ...                          ...  ..   ...              ...
# 16623      V5299              Hearing service   B   NaN              NaN
# 16624      V5336  Repair communication device  E1   NaN              NaN
# 16625      V5362             Speech screening  E1   NaN              NaN
# 16626      V5363           Language screening  E1   NaN              NaN
# 16627      V5364          Dysphagia screening  E1   NaN              NaN
#
#        Payment Rate  National Unadjusted Copayment   \
# 0                NaN                            NaN
# 1                NaN                            NaN
# 2                NaN                            NaN
# 3                NaN                            NaN
# 4                NaN                            NaN
# ...              ...                            ...
# 16623            NaN                            NaN
# 16624            NaN                            NaN
# 16625            NaN                            NaN
# 16626            NaN                            NaN
# 16627            NaN                            NaN
#
#        Minimum Unadjusted Copayment   \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 16623                            NaN
# 16624                            NaN
# 16625                            NaN
# 16626                            NaN
# 16627                            NaN
#
#       Note: Actual copayments would be lower due to the cap on copayments at the Inpatient Deductible of $1,408.00  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 16623                                                NaN
# 16624                                                NaN
# 16625                                                NaN
# 16626                                                NaN
# 16627                                                NaN
#
#       * Indicates a Change
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 16623                   NaN
# 16624                   NaN
# 16625                   NaN
# 16626                   NaN
# 16627                   NaN
#
# [16628 rows x 10 columns]

# %%
phys_other_payments = pd.read_csv('Medicare_Provider_Util_Payment_PUF_CY2017.txt', sep='\t',low_memory=False)

# %%
phys_other_payments = phys_other_payments.drop(phys_other_payments.index[0])

# %%
phys_other_payments.rename(columns={'nppes_provider_last_org_name':'provider_last_org_name',
                          'nppes_provider_first_name':'provider_first_name',
                          'nppes_provider_mi':'provider_mi',
                          'nppes_credentials':'credentials',
                          'nppes_provider_gender ':'provider_gender',
                          'nppes_entity_code':'entity_code',
                          'nppes_provider_street1':'provider_street1',
                          'nppes_provider_street2':'provider_street2',
                          'nppes_provider_city':'provider_city',
                          'nppes_provider_zip':'zip',
                          'nppes_provider_state':'provider_state',
                          'nppes_provider_country':'country'},inplace=True)

# %%
phys_other_payments['zip'] = phys_other_payments['zip'].str[:5]

# %%
phys_other_payments = phys_other_payments[phys_other_payments.country == 'US']

# %%
phys_other_payments['zip'] = pd.to_numeric(phys_other_payments['zip'])

# %%
phys_other_payments['zip'] = phys_other_payments['zip'].apply(lambda x: '{0:0>5}'.format(x))

# %%
phys_other_payments.head()
# Out:
#           npi provider_last_org_name provider_first_name provider_mi  \
# 1  1003000126              ENKESHAFI             ARDALAN         NaN
# 2  1003000126              ENKESHAFI             ARDALAN         NaN
# 3  1003000126              ENKESHAFI             ARDALAN         NaN
# 4  1003000126              ENKESHAFI             ARDALAN         NaN
# 5  1003000126              ENKESHAFI             ARDALAN         NaN
#
#   credentials nppes_provider_gender entity_code provider_street1  \
# 1        M.D.                     M           I     900 SETON DR
# 2        M.D.                     M           I     900 SETON DR
# 3        M.D.                     M           I     900 SETON DR
# 4        M.D.                     M           I     900 SETON DR
# 5        M.D.                     M           I     900 SETON DR
#
#   provider_street2 provider_city    zip provider_state country  \
# 1              NaN    CUMBERLAND  21502             MD      US
# 2              NaN    CUMBERLAND  21502             MD      US
# 3              NaN    CUMBERLAND  21502             MD      US
# 4              NaN    CUMBERLAND  21502             MD      US
# 5              NaN    CUMBERLAND  21502             MD      US
#
#        provider_type medicare_participation_indicator place_of_service  \
# 1  Internal Medicine                                Y                F
# 2  Internal Medicine                                Y                F
# 3  Internal Medicine                                Y                F
# 4  Internal Medicine                                Y                F
# 5  Internal Medicine                                Y                F
#
#   hcpcs_code                                  hcpcs_description  \
# 1      99217                Hospital observation care discharge
# 2      99218     Hospital observation care typically 30 minutes
# 3      99219     Hospital observation care typically 50 minutes
# 4      99220  Hospital observation care typically 70 minutes...
# 5      99221  Initial hospital inpatient care, typically 30 ...
#
#   hcpcs_drug_indicator  line_srvc_cnt  bene_unique_cnt  bene_day_srvc_cnt  \
# 1                    N          100.0             96.0              100.0
# 2                    N           26.0             25.0               26.0
# 3                    N           52.0             51.0               52.0
# 4                    N           59.0             59.0               59.0
# 5                    N           16.0             16.0               16.0
#
#    average_Medicare_allowed_amt  average_submitted_chrg_amt  \
# 1                     73.398800                  325.780000
# 2                    100.080000                  449.000000
# 3                    136.380000                  614.000000
# 4                    190.363729                  755.932203
# 5                    101.680000                  462.812500
#
#    average_Medicare_payment_amt  average_Medicare_standard_amt
# 1                     56.827200                      57.492400
# 2                     78.460000                      79.306154
# 3                    102.807692                     103.895385
# 4                    141.293559                     142.865763
# 5                     79.710000                      80.750000

# %%
ZIP_to_CBSA.zip.astype(object)
# Out:
# 0        57445
# 1        57456
# 2        57441
# 3        57474
# 4        57401
#          ...
# 47410    95922
# 47411    95920
# 47412    95665
# 47413    95689
# 47414    95254
# Name: zip, Length: 47415, dtype: object
