# %%
import pandas as pd 
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
Medicare_Provider_DF = pd.read_csv('c:/Users/t_d_o/Documents/healthcare-bluebook-orange-team/data/Medicare_Provider_Util_Payment_PUF_CY2017.txt', sep='\t', usecols = lambda column : column not in ['average_submitted_chrg_amt', 'average_Medicare_payment_amt', 'average_Medicare_standard_amt', 'nppes_provider_street2'], dtype={'nppes_provider_zip': 'str'})

# %%
Medicare_Provider_DF = Medicare_Provider_DF.drop(Medicare_Provider_DF.index[0])

# %%
Medicare_Provider_DF.dtypes
# Out:
# npi                                   int64
# nppes_provider_last_org_name         object
# nppes_provider_first_name            object
# nppes_provider_mi                    object
# nppes_credentials                    object
# nppes_provider_gender                object
# nppes_entity_code                    object
# nppes_provider_street1               object
# nppes_provider_city                  object
# nppes_provider_zip                   object
# nppes_provider_state                 object
# nppes_provider_country               object
# provider_type                        object
# medicare_participation_indicator     object
# place_of_service                     object
# hcpcs_code                           object
# hcpcs_description                    object
# hcpcs_drug_indicator                 object
# line_srvc_cnt                       float64
# bene_unique_cnt                     float64
# bene_day_srvc_cnt                   float64
# ...

# %%
Medicare_Provider_DF = Medicare_Provider_DF.rename(columns={'nppes_provider_city': 'city', 'nppes_provider_zip': 'zip', 'nppes_provider_state': 'state', 'nppes_provider_country': 'country'})

# %%
pd.options.display.max_columns = 25

# %%
Medicare_Provider_DF.dtypes
# Out:
# npi                                   int64
# nppes_provider_last_org_name         object
# nppes_provider_first_name            object
# nppes_provider_mi                    object
# nppes_credentials                    object
# nppes_provider_gender                object
# nppes_entity_code                    object
# nppes_provider_street1               object
# city                                 object
# zip                                  object
# state                                object
# country                              object
# provider_type                        object
# medicare_participation_indicator     object
# place_of_service                     object
# hcpcs_code                           object
# hcpcs_description                    object
# hcpcs_drug_indicator                 object
# line_srvc_cnt                       float64
# bene_unique_cnt                     float64
# bene_day_srvc_cnt                   float64
# ...

# %%
Medicare_Provider_DF = Medicare_Provider_DF[Medicare_Provider_DF.country == 'US']
Medicare_Provider_DF.head(n=5)
# Out:
#           npi nppes_provider_last_org_name nppes_provider_first_name  \
# 1  1003000126                    ENKESHAFI                   ARDALAN
# 2  1003000126                    ENKESHAFI                   ARDALAN
# 3  1003000126                    ENKESHAFI                   ARDALAN
# 4  1003000126                    ENKESHAFI                   ARDALAN
# 5  1003000126                    ENKESHAFI                   ARDALAN
#
#   nppes_provider_mi nppes_credentials nppes_provider_gender nppes_entity_code  \
# 1               NaN              M.D.                     M                 I
# 2               NaN              M.D.                     M                 I
# 3               NaN              M.D.                     M                 I
# 4               NaN              M.D.                     M                 I
# 5               NaN              M.D.                     M                 I
#
#   nppes_provider_street1        city        zip state country  \
# ...

# %%
Medicare_Provider_DF['zip'] = Medicare_Provider_DF['zip'].str[:5]

# %%
Medicare_Provider_DF.head(n=3)
# Out:
#           npi nppes_provider_last_org_name nppes_provider_first_name  \
# 1  1003000126                    ENKESHAFI                   ARDALAN
# 2  1003000126                    ENKESHAFI                   ARDALAN
# 3  1003000126                    ENKESHAFI                   ARDALAN
#
#   nppes_provider_mi nppes_credentials nppes_provider_gender nppes_entity_code  \
# 1               NaN              M.D.                     M                 I
# 2               NaN              M.D.                     M                 I
# 3               NaN              M.D.                     M                 I
#
#   nppes_provider_street1 nppes_provider_street2        city    zip state  \
# 1           900 SETON DR                    NaN  CUMBERLAND  21502    MD
# 2           900 SETON DR                    NaN  CUMBERLAND  21502    MD
# 3           900 SETON DR                    NaN  CUMBERLAND  21502    MD
#
#   country      provider_type medicare_participation_indicator  \
# ...

# %%
Medicare_Provider_DF.tail(n=3)
# Out:
#                 npi nppes_provider_last_org_name nppes_provider_first_name  \
# 9847441  1992999874                        JOFFE                 GABRIELLA
# 9847442  1992999874                        JOFFE                 GABRIELLA
# 9847443  1992999874                        JOFFE                 GABRIELLA
#
#         nppes_provider_mi nppes_credentials nppes_provider_gender  \
# 9847441               NaN               NaN                     F
# 9847442               NaN               NaN                     F
# 9847443               NaN               NaN                     F
#
#         nppes_entity_code nppes_provider_street1 nppes_provider_street2  \
# 9847441                 I          8260 ATLEE RD       MOB 2, SUITE 319
# 9847442                 I          8260 ATLEE RD       MOB 2, SUITE 319
# 9847443                 I          8260 ATLEE RD       MOB 2, SUITE 319
#
#                    city    zip state country      provider_type  \
# ...

# %% [markdown]
# # Hospital Charge

# %%
Provider_Outpatient_Hospital_Charge_DF = pd.read_csv('c:/Users/t_d_o/Documents/healthcare-bluebook-orange-team/data/Provider_Outpatient_Hospital_Charge_Data_by_APC__CY2017.csv')

# %%
Provider_Outpatient_Hospital_Charge_DF.head(n=3)
# Out:
#    Provider_ID                     Provider_Name Provider_Street_Address  \
# 0        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 1        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 2        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
#
#   Provider_City Provider_State  Provider_Zip_Code Provider_HRR   APC  \
# 0        Dothan             AL              36301  AL - Dothan  5072
# 1        Dothan             AL              36301  AL - Dothan  5073
# 2        Dothan             AL              36301  AL - Dothan  5091
#
#                                             APC_Desc  Beneficiaries  \
# 0    Level 2 Excision/ Biopsy/ Incision and Drainage          249.0
# 1    Level 3 Excision/ Biopsy/ Incision and Drainage           52.0
# 2  Level 1 Breast/Lymphatic Surgery and Related P...           26.0
#
#    CAPC_Services  Average_Total_Submitted_Charges  \
# 0            259                          9575.01
# ...

# %%
Provider_Outpatient_Hospital_Charge_DF.tail(n=3)
# Out:
#        Provider_ID                             Provider_Name  \
# 61776       670122  Houston Methodist The Woodlands Hospital
# 61777       670122  Houston Methodist The Woodlands Hospital
# 61778       670122  Houston Methodist The Woodlands Hospital
#
#          Provider_Street_Address  Provider_City Provider_State  \
# 61776  17201 Interstate 45 South  The Woodlands             TX
# 61777  17201 Interstate 45 South  The Woodlands             TX
# 61778  17201 Interstate 45 South  The Woodlands             TX
#
#        Provider_Zip_Code  Provider_HRR   APC  \
# 61776              77385  TX - Houston  5375
# 61777              77385  TX - Houston  5431
# 61778              77385  TX - Houston  8011
#
#                                    APC_Desc  Beneficiaries  CAPC_Services  \
# 61776  Level 5 Urology and Related Services           20.0             21
# 61777              Level 1 Nerve Procedures            NaN             12
# ...

# %%
Provider_Outpatient_Hospital_Charge_DF.dtypes
# Out:
# Provider_ID                          int64
# Provider_Name                       object
# Provider_Street_Address             object
# Provider_City                       object
# Provider_State                      object
# Provider_Zip_Code                    int64
# Provider_HRR                        object
# APC                                  int64
# APC_Desc                            object
# Beneficiaries                      float64
# CAPC_Services                        int64
# Average_Total_Submitted_Charges    float64
# Average_Medicare_Allowed_Amount    float64
# Average_Medicare_Payment_Amount    float64
# Outlier_Services                   float64
# Average_Medicare_Outlier_Amount    float64
# dtype: object

# %%
Provider_Outpatient_Hospital_Charge_DF['Provider_Zip_Code'] = pd.to_numeric(Provider_Outpatient_Hospital_Charge_DF['Provider_Zip_Code'])
Provider_Outpatient_Hospital_Charge_DF['Provider_Zip_Code'] = Provider_Outpatient_Hospital_Charge_DF['Provider_Zip_Code'].apply(lambda x: '{0:0>5}'.format(x))

# %%
CBSA_ZIP = pd.read_excel('c:/Users/t_d_o/Documents/healthcare-bluebook-orange-team/data/CBSA_DIV_ZIP_032020.xlsx', usecols = lambda column : column not in ['RES_RATIO', 'BUS_RATIO', 'OTH_RATIO', 'TOT_RATIO'])
CBSA_ZIP
# Out:
#       CBSA_DIV    ZIP
# 0        11244  92833
# 1        11244  92735
# 2        11244  92610
# 3        11244  92609
# 4        11244  92605
# ...        ...    ...
# 5380     48864  19730
# 5381     48864  19896
# 5382     48864  19805
# 5383     48864  19713
# 5384     48864  19712
#
# [5385 rows x 2 columns]

# %%
2020_january_web_addendum_b_df = pd.read_excel('../data/January 2020 Addendum B CORRECTION.02042020.xlsx', header = 2)
2020_january_web_addendum_b_df
# Out:
#   File "<ipython-input-55-a83a4b93092e>", line 1
#     2020_january_web_addendum_b_df = pd.read_excel('../data/January 2020 Addendum B CORRECTION.02042020.xlsx', header = 2)
#         ^
# SyntaxError: invalid token
